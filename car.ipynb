# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/cars.csv')
df
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
df.shape
# Out:
# (50, 2)

# %%
df.tail()
# Out:
#     speed  dist
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
df.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
df.describe()
# Out:
#            speed        dist
# count  50.000000   50.000000
# mean   15.400000   42.980000
# std     5.287644   25.769377
# min     4.000000    2.000000
# 25%    12.000000   26.000000
# 50%    15.000000   36.000000
# 75%    19.000000   56.000000
# max    25.000000  120.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   speed   50 non-null     int64
#  1   dist    50 non-null     int64
# dtypes: int64(2)
# memory usage: 928.0 bytes

# %%
core=df.corr()
plt.subplots(figsize=(10,5))
sns.heatmap(core,annot=True,linewidth=0.2)
plt.show()

# %%
df.columns
# Out:
# Index(['speed', 'dist'], dtype='object')

# %%
y=df['speed']
x=df.drop(['speed'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.25)

# %%
x_test
# Out:
#     dist
# 47    93
# 7     26
# 2      4
# 9     17
# 5     10
# 26    32
# 13    24
# 37    68
# 0      2
# 19    26
# 20    36
# 18    46
# 16    34

# %%
y_test
# Out:
# 47    24
# 7     10
# 2      7
# 9     11
# 5      9
# 26    16
# 13    12
# 37    19
# 0      4
# 19    14
# 20    14
# 18    13
# 16    13
# Name: speed, dtype: int64

# %%
from sklearn import linear_model
lg=linear_model.LogisticRegression()
model=lg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
prediction=model.predict(x_test)

# %%
print(y_test)
# Out:
# 47    24
# 7     10
# 2      7
# 9     11
# 5      9
# 26    16
# 13    12
# 37    19
# 0      4
# 19    14
# 20    14
# 18    13
# 16    13
# Name: speed, dtype: int64

# %%
print(prediction)
# Out:
# [24 15 12 12 12 15 12 18 12 15 17 20 15]

# %%
from sklearn.metrics import mean_squared_error

# %%
print('MCS IS:',mean_squared_error(y_test,prediction))
# Out:
# MCS IS: 14.538461538461538
